# %%
import pandas as pd

# %% [markdown]
# #Write a Python program using Pandas to create a DataFrame from the given data and calculate the average rating of movies directed by Christopher Nolan.

# %%
data = {

    'Title': ['Inception', 'Dunkirk', 'Interstellar', 'The Prestige', 'Memento'],

    'Director': ['Christopher Nolan', 'Christopher Nolan', 'Christopher Nolan', 'Christopher Nolan', 'Christopher Nolan'],

    'Rating': [8.8, 7.9, 8.6, 8.5, 8.4]

}

df1 = pd.DataFrame(data) #creating the data frame
df1
# Out:
#           Title           Director  Rating
# 0     Inception  Christopher Nolan     8.8
# 1       Dunkirk  Christopher Nolan     7.9
# 2  Interstellar  Christopher Nolan     8.6
# 3  The Prestige  Christopher Nolan     8.5
# 4       Memento  Christopher Nolan     8.4

# %%
#calculate the average rating of movies directed by Christopher Nolan.

Nolan_movies = df1[df1['Director'] == 'Christopher Nolan']
print(Nolan_movies)
print()
average_ratings = Nolan_movies['Rating'].mean()
print(average_ratings)
# Out:
#           Title           Director  Rating
# 0     Inception  Christopher Nolan     8.8
# 1       Dunkirk  Christopher Nolan     7.9
# 2  Interstellar  Christopher Nolan     8.6
# 3  The Prestige  Christopher Nolan     8.5
# 4       Memento  Christopher Nolan     8.4
#
# 8.440000000000001

# %% [markdown]
# #Given the following DataFrame, write a Python program using Pandas to extract all rows where the price is greater than or equal to 20,000 and sort them in descending order by price.

# %%
data = {

    'Product': ['Laptop', 'Desktop', 'Tablet', 'Phone', 'Smartwatch'],

    'Price': [25000, 12000, 8000, 22000, 5000]

}



df2 = pd.DataFrame(data)

df2
# Out:
#       Product  Price
# 0      Laptop  25000
# 1     Desktop  12000
# 2      Tablet   8000
# 3       Phone  22000
# 4  Smartwatch   5000

# %%
#extract all rows where the price is greater than or equal to 20,000

filtered_rows = df2[df2['Price']>=2000]
filtered_rows
# Out:
#       Product  Price
# 0      Laptop  25000
# 1     Desktop  12000
# 2      Tablet   8000
# 3       Phone  22000
# 4  Smartwatch   5000

# %%
#sort them in descending order by price.

filtered_rows = filtered_rows.sort_values('Price',ascending= False).reset_index()
filtered_rows
# Out:
#    index     Product  Price
# 0      0      Laptop  25000
# 1      3       Phone  22000
# 2      1     Desktop  12000
# 3      2      Tablet   8000
# 4      4  Smartwatch   5000

# %% [markdown]
# #Write a Python program using Pandas to create a DataFrame from the given data and find the total revenue and average price of items sold in each store.

# %%
data = {

    'Store': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],

    'Item': ['Apple', 'Banana', 'Orange', 'Grape', 'Apple', 'Banana', 'Orange', 'Grape'],

    'Price': [50, 20, 30, 60, 55, 22, 33, 65],

    'Quantity': [10, 12, 15, 16, 20, 25, 30, 35]

}

df3 = pd.DataFrame(data)
df3
# Out:
#   Store    Item  Price  Quantity
# 0     A   Apple     50        10
# 1     B  Banana     20        12
# 2     A  Orange     30        15
# 3     B   Grape     60        16
# 4     A   Apple     55        20
# 5     B  Banana     22        25
# 6     A  Orange     33        30
# 7     B   Grape     65        35

# %%
#find the total revenue and average price of items sold in each store
df3['Revenue'] = df3['Price'] * df3['Quantity']
each_store_details = df3.groupby('Store').agg({'Price' : 'mean', 'Quantity' :'sum','Revenue' : 'sum'}).reset_index()

each_store_details
# Out:
#   Store  Price  Quantity  Revenue
# 0     A  42.00        75     3040
# 1     B  41.75        88     4025

# %% [markdown]
# #Write a Python program using Pandas to create a DataFrame from the given data and calculate the total amount spent by each customer.

# %%
data = {

    'Customer': ['Alice', 'Bob', 'Alice', 'Alice', 'Bob', 'Bob', 'Alice', 'Bob'],

    'Item': ['Pen', 'Pencil', 'Notebook', 'Eraser', 'Pen', 'Pencil', 'Notebook', 'Eraser'],

    'Price': [10, 5, 50, 20, 10, 5, 50, 20],

    'Quantity': [3, 4, 2, 5, 10, 6, 1, 2]

}

df4 = pd.DataFrame(data)
df4
# Out:
#   Customer      Item  Price  Quantity
# 0    Alice       Pen     10         3
# 1      Bob    Pencil      5         4
# 2    Alice  Notebook     50         2
# 3    Alice    Eraser     20         5
# 4      Bob       Pen     10        10
# 5      Bob    Pencil      5         6
# 6    Alice  Notebook     50         1
# 7      Bob    Eraser     20         2

# %%
#calculate the total amount spent by each customer

df4['Total_spent'] = df4['Price'] * df4['Quantity']

customer_expenditure = df4.groupby('Customer').agg({'Total_spent' : 'sum'}).reset_index()
customer_expenditure
# Out:
#   Customer  Total_spent
# 0    Alice          280
# 1      Bob          190

# %% [markdown]
# #Write a Python program using Pandas to create a DataFrame from the given data and find the month with the highest average temperature.

# %%
data = {

    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],

    'Temperature': [20, 22, 25, 27, 30, 32, 35, 34, 30, 28, 24, 21]

}
df5 = pd.DataFrame(data)
df5
# Out:
#    Month  Temperature
# 0    Jan           20
# 1    Feb           22
# 2    Mar           25
# 3    Apr           27
# 4    May           30
# 5    Jun           32
# 6    Jul           35
# 7    Aug           34
# 8    Sep           30
# 9    Oct           28
# 10   Nov           24
# 11   Dec           21

# %%
#find the month with the highest average temperature.
temperature_df = df5.sort_values('Temperature',ascending= False)
hottest_month = temperature_df.iloc[0]['Month']
hottest_month
# Out:
# 'Jul'

# %%
data = {

    'Category': ['Fruit', 'Vegetable', 'Fruit', 'Vegetable', 'Fruit', 'Vegetable'],

    'Name': ['Apple', 'Carrot', 'Banana', 'Potato', 'Grape', 'Onion'],

    'Price': [2, 1, 1.5, 0.5, 3, 1],

    'Quantity': [10, 20, 15, 30, 5, 40]

}



df = pd.DataFrame(data)



fruits = df[df['Category'] == 'Fruit']
fruits
# Out:
#   Category    Name  Price  Quantity
# 0    Fruit   Apple    2.0        10
# 2    Fruit  Banana    1.5        15
# 4    Fruit   Grape    3.0         5

# %%
data = {

    'Name': ['Alice', 'Bob', 'Charlie', 'David'],

    'Age': [25, 30, 35, 40],

    'City': ['New York', 'San Francisco', 'Los Angeles', 'Chicago']

}



df = pd.DataFrame(data)
df
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   40        Chicago

# %% [markdown]
# #Write a Python program using Pandas to create a DataFrame from the given data and find the total amount spent per item, as well as the total amount spent by all customers.

# %%
data = {

    'Customer': ['Alice', 'Bob', 'Alice', 'Alice', 'Bob', 'Bob', 'Alice', 'Bob'],

    'Item': ['Pen', 'Pencil', 'Notebook', 'Eraser', 'Pen', 'Pencil', 'Notebook', 'Eraser'],

    'Price': [10, 5, 50, 20, 10, 5, 50, 20],

    'Quantity': [3, 4, 2, 5, 10, 6, 1, 2]

}

df6 = pd.DataFrame(data)
df6
# Out:
#   Customer      Item  Price  Quantity
# 0    Alice       Pen     10         3
# 1      Bob    Pencil      5         4
# 2    Alice  Notebook     50         2
# 3    Alice    Eraser     20         5
# 4      Bob       Pen     10        10
# 5      Bob    Pencil      5         6
# 6    Alice  Notebook     50         1
# 7      Bob    Eraser     20         2

# %%
#find the total amount spent per item
df6['total_spent_for_item'] = df6['Price'] * df6['Quantity']
total_spent_item = df6.groupby('Item').agg({'total_spent_for_item' : 'sum'})
total_spent_item
# Out:
#           total_spent_for_item
# Item
# Eraser                     140
# Notebook                   150
# Pen                        130
# Pencil                      50

# %%
#total amount spent by all customers.

total_amount = df6['total_spent_for_item'].sum()
total_amount
# Out:
# np.int64(470)

# %% [markdown]
#  Write a Python program using Pandas to create a DataFrame from the given data and calculate the monthly average temperature difference between two cities.

# %%
data = {

    'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],

    'City_A_Temp': [20, 22, 25, 27, 30, 32, 35, 34, 30, 28, 24, 21],

    'City_B_Temp': [10, 12, 15, 17, 20, 22, 25, 24, 20, 18, 14, 11]

}



df7 = pd.DataFrame(data)
df7
# Out:
#    Month  City_A_Temp  City_B_Temp
# 0    Jan           20           10
# 1    Feb           22           12
# 2    Mar           25           15
# 3    Apr           27           17
# 4    May           30           20
# 5    Jun           32           22
# 6    Jul           35           25
# 7    Aug           34           24
# 8    Sep           30           20
# 9    Oct           28           18
# 10   Nov           24           14
# 11   Dec           21           11

# %%
#calculate the monthly average temperature difference between two cities.

df7['temperature_difference'] = df7['City_A_Temp'] - df7['City_B_Temp']

average_temperature_difference = df7['temperature_difference'].mean()
average_temperature_difference
# Out:
# np.float64(10.0)
